# %%
# %matplotlib inline
# %matplotlib notebook

# %%
import compareTilt
import matplotlib.pyplot as plt
# Out:
# Opening result  dsres_Tilt00.mat  in  2.1359591484069824  s
# Opening result  dsres_Tilt30.mat  in  4.303950548171997  s
# Opening result  dsres_Tilt60.mat  in  6.475950479507446  s
# Opening result  dsres_Tilt90.mat  in  8.659950256347656  s
# For 0° tilt:
#   brachial_L82_HL at 0.0 cm
#   femoral_R226 at 0.0 cm
#   internal_carotid_R8_B at 0.0 cm
#   thoracic_aorta_C108 at 0.0 cm
#   tibiofibular_trunk_R234 at 0.0 cm
# For 30° tilt:
#   brachial_L82_HL at 0.0 cm
#   femoral_R226 at -30.6 cm
#   internal_carotid_R8_B at 11.2 cm
#   thoracic_aorta_C108 at 0.6 cm
#   tibiofibular_trunk_R234 at -46.5 cm
# For 60° tilt:
#   brachial_L82_HL at 0.0 cm
#   femoral_R226 at -53.0 cm
#   internal_carotid_R8_B at 19.3 cm
#   thoracic_aorta_C108 at 1.0 cm
#   tibiofibular_trunk_R234 at -80.6 cm
# For 90° tilt:
#   brachial_L82_HL at 0.0 cm
#   femoral_R226 at -61.2 cm
#   internal_carotid_R8_B at 22.3 cm
#   thoracic_aorta_C108 at 1.2 cm
#   tibiofibular_trunk_R234 at -93.1 cm

# %%
plt.clf()
plt.plot([0, 1],[2, 3])
plt.plot([0, 1],[2, 4])
plt.figure(2)
plt.plot([0, 1],[2, 1])
